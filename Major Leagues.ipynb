# %%
import csv
import math
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

# To print data in tabular format
from tabulate import tabulate

# %%
#reading user-rating data file 
nfl_df = pd.read_csv('./data/nfl_games.csv', parse_dates = ['date'], index_col = ['date'])

#converting Order_Demand as int
nfl_df['result1']=nfl_df['result1'].astype(int)

# %%
display(nfl_df)
# Out:
#             season  neutral  playoff team1 team2         elo1         elo2  \
# date
# 1920-09-26    1920        0        0   RII   STP  1503.947000  1300.000000
# 1920-10-03    1920        0        0   AKR   WHE  1503.420000  1300.000000
# 1920-10-03    1920        0        0   RCH   ABU  1503.420000  1300.000000
# 1920-10-03    1920        0        0   DAY   COL  1493.002000  1504.908000
# 1920-10-03    1920        0        0   RII   MUN  1516.108000  1478.004000
# ...            ...      ...      ...   ...   ...          ...          ...
# 2019-01-13    2018        0        1    NE   LAC  1640.171960  1647.624483
# 2019-01-13    2018        0        1    NO   PHI  1669.105861  1633.114673
# 2019-01-20    2018        0        1    NO   LAR  1682.450194  1648.424105
# 2019-01-20    2018        0        1    KC    NE  1675.286412  1661.668566
# 2019-02-03    2018        1        1   LAR    NE  1666.969395  1686.338837
#
#             elo_prob1  score1  score2  result1
# date
# 1920-09-26   0.824651      48       0        1
# 1920-10-03   0.824212      43       0        1
# 1920-10-03   0.824212      10       0        1
# 1920-10-03   0.575819      14       0        1
# 1920-10-03   0.644171      45       0        1
# ...               ...     ...     ...      ...
# 2019-01-13   0.582068      41      28        1
# 2019-01-13   0.641378      20      14        1
# 2019-01-20   0.638772      23      26        0
# 2019-01-20   0.611248      31      37        0
# 2019-02-03   0.472154       3      13        0
#
# [16274 rows x 11 columns]

# %% [markdown]
# The above dataframe contains the game results played b/w different teams having scores of each team and finally the result. '1' means team1 won that match and '0' means team2 won the match.

# %%
display(nfl_df.describe())
# Out:
#              season       neutral       playoff          elo1          elo2  \
# count  16274.000000  16274.000000  16274.000000  16274.000000  16274.000000
# mean    1982.437569      0.005223      0.034779   1502.458394   1498.918374
# std       25.448049      0.072084      0.183226    105.015371    104.541270
# min     1920.000000      0.000000      0.000000   1119.595000   1156.551000
# 25%     1967.000000      0.000000      0.000000   1429.242750   1425.864750
# 50%     1987.000000      0.000000      0.000000   1504.015000   1500.185000
# 75%     2003.000000      0.000000      0.000000   1578.071500   1575.753000
# max     2018.000000      1.000000      1.000000   1839.663000   1849.484000
#
#           elo_prob1        score1        score2       result1
# count  16274.000000  16274.000000  16274.000000  16274.000000
# mean       0.584825     21.544058     18.578161      0.571034
# std        0.175310     11.289422     10.794566      0.494944
# min        0.070953      0.000000      0.000000      0.000000
# 25%        0.461231     14.000000     10.000000      0.000000
# 50%        0.596354     21.000000     17.000000      1.000000
# 75%        0.719904     28.000000     26.000000      1.000000
# max        0.970516     72.000000     73.000000      1.000000

# %%
display(nfl_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16274 entries, 1920-09-26 to 2019-02-03
# Data columns (total 11 columns):
# season       16274 non-null int64
# neutral      16274 non-null int64
# playoff      16274 non-null int64
# team1        16274 non-null object
# team2        16274 non-null object
# elo1         16274 non-null float64
# elo2         16274 non-null float64
# elo_prob1    16274 non-null float64
# score1       16274 non-null int64
# score2       16274 non-null int64
# result1      16274 non-null int32
# dtypes: float64(3), int32(1), int64(5), object(2)
# memory usage: 1.4+ MB
# None

# %%
# total number of games
total_games = len(nfl_df)

# total number of home wins
home_wins = 0
for i in nfl_df.result1:
    if i == 1:
        home_wins+=1

# total home wins/total number of games
home_win_rate = home_wins/total_games

print("Home Team Win Rate: {:.2f}% ".format(home_win_rate*100))
# Out:
# Home Team Win Rate: 57.10%

# %% [markdown]
# In, above we are getting the Home Team Win rate as we can see from the above data result it is 57.10%.

# %%
HFA = 65.0     # Home field advantage is worth 65 Elo points
K = 20.0       # The speed at which Elo ratings change
REVERT = 1/3.0 # Between seasons, a team retains 2/3 of its previous season's rating

# Some between-season reversions of unknown origin
REVERSIONS = {'CBD1925': 1502.032, 
              'RAC1926': 1403.384, 
              'LOU1926': 1307.201, 
              'CIB1927': 1362.919, 
              'MNN1929': 1306.702,
              'BFF1929': 1331.943, 
              'LAR1944': 1373.977, 
              'PHI1944': 1497.988, 
              'ARI1945': 1353.939, 
              'PIT1945': 1353.939, 
              'CLE1999': 1300.0}

# %% [markdown]
# #### HFA = 65.0 :
# Home field advantage is worth 65 Elo points.
#
# #### The K-factor:
# It regulates how quickly the ratings change in response to new information. A high K-factor tells Elo to be very sensitive to recent results, causing the ratings to jump around a lot based on each game’s outcome; a low K-factor makes Elo slow to change its opinion about teams, since every game carries comparatively little weight. In our NFL research, we found that the ideal K-factor for predicting future games is 20 — large enough that new results carry weight, but not so large that the ratings bounce around each week.

# %%
""" Initializes game objects from csv """
games = [item for item in csv.DictReader(open("./data/nfl_games.csv"))]

# Uncommenting these three lines will grab the latest game results for 2019, update team ratings accordingly, and make forecasts for upcoming games

games += [item for item in csv.DictReader(open('./data/nfl_games_2019.csv'))]

for game in games:
    game['season'], game['neutral'], game['playoff'] = int(game['season']), int(game['neutral']), int(game['playoff'])
    game['score1'], game['score2'] = int(game['score1']) if game['score1'] != '' else None, int(game['score2']) if game['score2'] != '' else None
    game['elo_prob1'], game['result1'] = float(game['elo_prob1']) if game['elo_prob1'] != '' else None, float(game['result1']) if game['result1'] != '' else None

# %% [markdown]
# In above code, reading the nfl_games CSV file and putting each data as dictionary.
#
# Then, opening another CSV file which have the nfl_game list of 2019 which is not happened yet and I'm going to find out the winning probablity of the team.

# %%
header = games[0].keys()
rows=[]
counter =0
for x in games:
    rows.append(x.values())
    
    counter+=1
    if counter==20:
        break
        
        
print(tabulate(rows, header,tablefmt='simple'))
# Out:
# date          season    neutral    playoff  team1    team2       elo1     elo2    elo_prob1    score1    score2    result1
# ----------  --------  ---------  ---------  -------  -------  -------  -------  -----------  --------  --------  ---------
# 9-26-1920       1920          0          0  RII      STP      1503.95  1300        0.824651        48         0        1
for row in [item for item in csv.DictReader(open("./data/initial_elos.csv"))]:
    teams[row['team']] = {
        'name': row['team'],
        'season': None,
        'elo': float(row['elo'])
    }

# %% [markdown]
# In the above code, Opening other file having Elo rating of each team.  I'm initializing team objects to maintain ratings and by deafult season is None.

# %%
header = ['Name', 'Season', 'elo']
rows=[]
counter =0
for x in teams.items():
    rows.append([x[1]['name'], x[1]['season'],x[1]['elo']])      
        
print(tabulate(rows,header, tablefmt='grid'))
# Out:
# +--------+----------+---------+
# | Name   | Season   |     elo |
# +========+==========+=========+
# | RII    |          | 1503.95 |
# +--------+----------+---------+
# | STP    |          | 1300    |
# +--------+----------+---------+
# | BFF    |          | 1478    |
# +--------+----------+---------+
# | WBU    |          | 1300    |
# +--------+----------+---------+
# | RCH    |          | 1503.42 |
# +--------+----------+---------+
# | ABU    |          | 1300    |
# +--------+----------+---------+
# | DAY    |          | 1493    |
# +--------+----------+---------+
# | COL    |          | 1504.91 |
# +--------+----------+---------+
# | MUN    |          | 1478    |
# +--------+----------+---------+
# | CHI    |          | 1368.33 |
# +--------+----------+---------+
# | MUT    |          | 1300    |
# +--------+----------+---------+
# | CBD    |          | 1504.69 |
# +--------+----------+---------+
# | PTQ    |          | 1300    |
# +--------+----------+---------+
# | AKR    |          | 1503.42 |
# +--------+----------+---------+
# | WHE    |          | 1300    |
# +--------+----------+---------+
# | DHR    |          | 1499.67 |
# +--------+----------+---------+
# | CLP    |          | 1300    |
# +--------+----------+---------+
# | CHT    |          | 1300    |
# +--------+----------+---------+
# | ARI    |          | 1493    |
# +--------+----------+---------+
# | CTI    |          | 1464.51 |
# +--------+----------+---------+
# | FTP    |          | 1300    |
# +--------+----------+---------+
# | HAM    |          | 1444.26 |
# +--------+----------+---------+
# | KEW    |          | 1300    |
# +--------+----------+---------+
# | TLM    |          | 1300    |
# +--------+----------+---------+
# | MCK    |          | 1300    |
# +--------+----------+---------+
# | UTI    |          | 1300    |
# +--------+----------+---------+
# | CNC    |          | 1300    |
# +--------+----------+---------+
# | FTW    |          | 1300    |
# +--------+----------+---------+
# | SYR    |          | 1300    |
# +--------+----------+---------+
# | LOG    |          | 1300    |
# +--------+----------+---------+
# | RCK    |          | 1300    |
# +--------+----------+---------+
# | ZAN    |          | 1300    |
# +--------+----------+---------+
# | ATN    |          | 1300    |
# +--------+----------+---------+
# | PUL    |          | 1300    |
# +--------+----------+---------+
# | THO    |          | 1300    |
# +--------+----------+---------+
# | CHL    |          | 1300    |
# +--------+----------+---------+
# | GAR    |          | 1300    |
# +--------+----------+---------+
# | MNM    |          | 1300    |
# +--------+----------+---------+
# | ROS    |          | 1300    |
# +--------+----------+---------+
# | LAN    |          | 1300    |
# +--------+----------+---------+
# | ELY    |          | 1300    |
# +--------+----------+---------+
# | CHB    |          | 1300    |
# +--------+----------+---------+
# | WJA    |          | 1300    |
# +--------+----------+---------+
# | WGC    |          | 1300    |
# +--------+----------+---------+
# +--------+----------+---------+
# | BCL    |          | 1300    |
# +--------+----------+---------+
# | NYY    |          | 1300    |
# +--------+----------+---------+
# | DTX    |          | 1300    |
# +--------+----------+---------+
# | IND    |          | 1300    |
# +--------+----------+---------+
# | NE     |          | 1300    |
# +--------+----------+---------+
# | DEN    |          | 1300    |
# +--------+----------+---------+
# | LAC    |          | 1300    |
# +--------+----------+---------+
# | KC     |          | 1300    |
# +--------+----------+---------+
# | OAK    |          | 1300    |
# +--------+----------+---------+
# | TEN    |          | 1300    |
# +--------+----------+---------+
# | NYJ    |          | 1300    |
# +--------+----------+---------+
# | BUF    |          | 1300    |
# +--------+----------+---------+
# | DAL    |          | 1300    |
# +--------+----------+---------+
# | MIN    |          | 1300    |
# +--------+----------+---------+
# | MIA    |          | 1300    |
# +--------+----------+---------+
# | ATL    |          | 1300    |
# +--------+----------+---------+
# | NO     |          | 1300    |
# +--------+----------+---------+
# | CIN    |          | 1300    |
# +--------+----------+---------+
# | TB     |          | 1300    |
# +--------+----------+---------+
# | SEA    |          | 1300    |
# +--------+----------+---------+
# | CAR    |          | 1300    |
# +--------+----------+---------+
# | JAX    |          | 1300    |
# +--------+----------+---------+
# | BAL    |          | 1432.22 |
# +--------+----------+---------+
# | HOU    |          | 1300    |
# +--------+----------+---------+

# %% [markdown]
# Note: Season value is None that's why Season column is showing blank because I'm using tabulate to print the data.

# %%
for game in games:
    team1, team2 = teams[game['team1']], teams[game['team2']]

    # Revert teams at the start of seasons
    for team in [team1, team2]:
        if team['season'] and game['season'] != team['season']:
            k = "%s%s" % (team['name'], game['season'])
            if k in REVERSIONS:
                team['elo'] = REVERSIONS[k]
            else:
                team['elo'] = 1505.0*REVERT + team['elo']*(1-REVERT)
        team['season'] = game['season']
 

    # Elo difference includes home field advantage
    elo_diff = team1['elo'] - team2['elo'] + (0 if game['neutral'] == 1 else HFA)

    # This is the most important piece, where we set my_prob1 to our forecasted probability
    if game['elo_prob1'] != None:
        game['my_prob1'] = 1.0 / (math.pow(10.0, (-elo_diff/400.0)) + 1.0)

    # If game was played, maintain team Elo ratings
    if game['score1'] != None:

        # Margin of victory is used as a K multiplier
        pd = abs(game['score1'] - game['score2'])
        mult = math.log(max(pd, 1) + 1.0) * (2.2 / (1.0 if game['result1'] == 0.5 else ((elo_diff if game['result1'] == 1.0 else -elo_diff) * 0.001 + 2.2)))

        # Elo shift based on K and the margin of victory multiplier
        shift = (K * mult) * (game['result1'] - game['my_prob1'])

        # Apply shift
        team1['elo'] += shift
        team2['elo'] -= shift

# %% [markdown]
# In above code, for each games i'm finding out the winning probabilty. The winning probability is for team1 only. If probabilty is more than 50% than Team1 will have more winning chances else Team2 have more winning chances.

# %%
""" Evaluates and scores forecasts in the my_prob1 field against those in the elo_prob1 field for each game """
my_points_by_season, elo_points_by_season = {}, {}

forecasted_games = [g for g in games if g['result1'] != None]
upcoming_games = [g for g in games if g['result1'] == None and 'my_prob1' in g]

# Evaluate forecasts and group by season
for game in forecasted_games:

    # Skip unplayed games and ties
    if game['result1'] == None or game['result1'] == 0.5:
        continue

    if game['season'] not in elo_points_by_season:
        elo_points_by_season[game['season']] = 0.0
        my_points_by_season[game['season']] = 0.0

    # Calculate elo's points for game
    rounded_elo_prob = round(game['elo_prob1'], 2)
    elo_brier = (rounded_elo_prob - game['result1']) * (rounded_elo_prob - game['result1'])
    elo_points = 25 - (100 * elo_brier)
    elo_points = round(elo_points + 0.001 if elo_points < 0 else elo_points, 1) # Round half up
    if game['playoff'] == 1:
        elo_points *= 2
    elo_points_by_season[game['season']] += elo_points

    # Calculate my points for game
    rounded_my_prob = round(game['my_prob1'], 2)
    my_brier = (rounded_my_prob - game['result1']) * (rounded_my_prob - game['result1'])
    my_points = 25 - (100 * my_brier)
    my_points = round(my_points + 0.001 if my_points < 0 else my_points, 1) # Round half up
    if game['playoff'] == 1:
        my_points *= 2
    my_points_by_season[game['season']] += my_points

# Print individual seasons
for season in my_points_by_season:
    print("In %s, your forecasts would have gotten %s points. Elo got %s points." % (season, round(my_points_by_season[season], 2), round(elo_points_by_season[season], 2)))
# Out:
# In 1920, your forecasts would have gotten 719.4 points. Elo got 719.4 points.
# In 1921, your forecasts would have gotten 481.1 points. Elo got 481.1 points.
# In 1922, your forecasts would have gotten 609.3 points. Elo got 609.3 points.
# In 1923, your forecasts would have gotten 562.8 points. Elo got 562.8 points.
# In 1924, your forecasts would have gotten 481.3 points. Elo got 481.3 points.
# In 1925, your forecasts would have gotten 653.6 points. Elo got 653.6 points.
# In 1926, your forecasts would have gotten 700.0 points. Elo got 700.0 points.
# In 1927, your forecasts would have gotten 173.1 points. Elo got 173.1 points.
# In 1928, your forecasts would have gotten 151.9 points. Elo got 151.9 points.
# In 1929, your forecasts would have gotten 659.7 points. Elo got 659.7 points.
# In 1930, your forecasts would have gotten 409.8 points. Elo got 409.8 points.
# In 1931, your forecasts would have gotten 414.6 points. Elo got 414.6 points.
# In 1932, your forecasts would have gotten 217.1 points. Elo got 217.1 points.
# In 1933, your forecasts would have gotten 321.7 points. Elo got 321.7 points.
# In 1934, your forecasts would have gotten 519.1 points. Elo got 519.1 points.
# In 1935, your forecasts would have gotten 183.3 points. Elo got 183.3 points.
# In 1936, your forecasts would have gotten 440.3 points. Elo got 440.3 points.
# In 1937, your forecasts would have gotten 218.7 points. Elo got 218.7 points.
# In 1938, your forecasts would have gotten 121.0 points. Elo got 121.0 points.
# In 1939, your forecasts would have gotten 607.4 points. Elo got 607.4 points.
# In 1940, your forecasts would have gotten 329.1 points. Elo got 329.1 points.
# In 1941, your forecasts would have gotten 547.2 points. Elo got 547.2 points.
# In 1942, your forecasts would have gotten 422.9 points. Elo got 422.9 points.
# In 1943, your forecasts would have gotten 377.2 points. Elo got 377.2 points.
# In 1944, your forecasts would have gotten 433.0 points. Elo got 433.0 points.
# In 1945, your forecasts would have gotten 309.7 points. Elo got 309.7 points.
# In 1946, your forecasts would have gotten 257.6 points. Elo got 257.6 points.
# In 1947, your forecasts would have gotten 744.7 points. Elo got 744.7 points.
# In 1948, your forecasts would have gotten 1105.2 points. Elo got 1105.2 points.
# In 1949, your forecasts would have gotten 830.8 points. Elo got 831.2 points.
# In 1950, your forecasts would have gotten 429.6 points. Elo got 429.6 points.
# In 1951, your forecasts would have gotten 190.5 points. Elo got 190.5 points.
# In 1952, your forecasts would have gotten 109.0 points. Elo got 109.0 points.
# In 1953, your forecasts would have gotten 491.0 points. Elo got 491.0 points.
# In 1954, your forecasts would have gotten 378.0 points. Elo got 378.0 points.
# In 1955, your forecasts would have gotten 110.7 points. Elo got 110.7 points.
# In 1956, your forecasts would have gotten 12.4 points. Elo got 12.4 points.
# In 1957, your forecasts would have gotten 29.7 points. Elo got 29.7 points.
# In 1958, your forecasts would have gotten 350.3 points. Elo got 350.3 points.
# In 1959, your forecasts would have gotten 163.9 points. Elo got 163.9 points.
# In 1960, your forecasts would have gotten 337.7 points. Elo got 337.7 points.
# In 1961, your forecasts would have gotten 794.9 points. Elo got 794.9 points.
# In 1962, your forecasts would have gotten 692.2 points. Elo got 692.2 points.
# In 1963, your forecasts would have gotten 643.8 points. Elo got 643.8 points.
# In 1964, your forecasts would have gotten 329.4 points. Elo got 329.4 points.
# In 1965, your forecasts would have gotten 383.3 points. Elo got 383.3 points.
# In 1966, your forecasts would have gotten 721.6 points. Elo got 721.6 points.
# In 1967, your forecasts would have gotten 938.8 points. Elo got 938.8 points.
# In 1968, your forecasts would have gotten 1062.9 points. Elo got 1062.9 points.
# In 1969, your forecasts would have gotten 1437.5 points. Elo got 1437.5 points.
# In 1970, your forecasts would have gotten 766.9 points. Elo got 766.9 points.
# In 1971, your forecasts would have gotten 660.3 points. Elo got 658.7 points.
# In 1972, your forecasts would have gotten 773.4 points. Elo got 773.4 points.
# In 1973, your forecasts would have gotten 1285.9 points. Elo got 1285.9 points.
# In 1974, your forecasts would have gotten 659.8 points. Elo got 659.8 points.
# In 1975, your forecasts would have gotten 1234.7 points. Elo got 1234.7 points.
# In 1976, your forecasts would have gotten 1470.1 points. Elo got 1470.1 points.
# In 1977, your forecasts would have gotten 1185.1 points. Elo got 1185.1 points.
# In 1978, your forecasts would have gotten 666.3 points. Elo got 666.3 points.
# In 1979, your forecasts would have gotten 604.9 points. Elo got 604.9 points.
# In 1980, your forecasts would have gotten 582.2 points. Elo got 582.2 points.
# In 1981, your forecasts would have gotten 372.3 points. Elo got 372.3 points.
# In 1982, your forecasts would have gotten 415.5 points. Elo got 415.5 points.
# In 1983, your forecasts would have gotten 304.9 points. Elo got 304.9 points.
# In 1984, your forecasts would have gotten 1054.5 points. Elo got 1054.5 points.
# In 1985, your forecasts would have gotten 1211.9 points. Elo got 1212.3 points.
# In 1986, your forecasts would have gotten 1078.6 points. Elo got 1078.6 points.
# In 1987, your forecasts would have gotten 210.0 points. Elo got 210.0 points.
# In 1988, your forecasts would have gotten 536.4 points. Elo got 536.4 points.
# In 1989, your forecasts would have gotten 743.1 points. Elo got 743.1 points.
# In 1990, your forecasts would have gotten 841.0 points. Elo got 841.0 points.
# In 1991, your forecasts would have gotten 1238.1 points. Elo got 1238.1 points.
# In 1992, your forecasts would have gotten 1002.1 points. Elo got 1002.1 points.
# In 1993, your forecasts would have gotten 573.6 points. Elo got 573.6 points.
# In 1994, your forecasts would have gotten 555.1 points. Elo got 555.1 points.
# In 1995, your forecasts would have gotten 592.9 points. Elo got 591.3 points.
# In 1996, your forecasts would have gotten 1022.7 points. Elo got 1022.7 points.
# In 1997, your forecasts would have gotten 785.5 points. Elo got 785.5 points.
# In 1998, your forecasts would have gotten 1381.4 points. Elo got 1381.4 points.
# In 1999, your forecasts would have gotten 697.9 points. Elo got 697.9 points.
# In 2000, your forecasts would have gotten 767.1 points. Elo got 767.1 points.
# In 2001, your forecasts would have gotten 571.3 points. Elo got 571.3 points.
# In 2002, your forecasts would have gotten 748.2 points. Elo got 748.2 points.
# In 2003, your forecasts would have gotten 811.4 points. Elo got 811.8 points.
# In 2004, your forecasts would have gotten 751.1 points. Elo got 751.1 points.
# In 2005, your forecasts would have gotten 1085.7 points. Elo got 1085.7 points.
# In 2006, your forecasts would have gotten 492.3 points. Elo got 492.3 points.
# In 2007, your forecasts would have gotten 895.6 points. Elo got 895.6 points.
# In 2008, your forecasts would have gotten 820.3 points. Elo got 820.3 points.
# In 2009, your forecasts would have gotten 1204.8 points. Elo got 1205.2 points.
# In 2010, your forecasts would have gotten 435.4 points. Elo got 435.4 points.
# In 2011, your forecasts would have gotten 968.9 points. Elo got 968.9 points.
# In 2012, your forecasts would have gotten 820.9 points. Elo got 820.9 points.
# In 2013, your forecasts would have gotten 989.6 points. Elo got 989.6 points.
# In 2014, your forecasts would have gotten 1222.0 points. Elo got 1222.0 points.
# In 2015, your forecasts would have gotten 707.1 points. Elo got 707.1 points.
# In 2016, your forecasts would have gotten 924.8 points. Elo got 924.8 points.
# In 2017, your forecasts would have gotten 892.0 points. Elo got 892.0 points.
# In 2018, your forecasts would have gotten 718.9 points. Elo got 718.9 points.
# In 2019, your forecasts would have gotten 114.7 points. Elo got 114.7 points.

# %% [markdown]
# Evaluating result by season.
#
# For each year first I'm calculating actual elo's points for games. After that I'm finding my probability elo's point.
# As we can see that actual and forecasted elo's points are the same.

# %%
# Show overall performance
my_avg = sum(my_points_by_season.values())/len(my_points_by_season.values())
elo_avg = sum(elo_points_by_season.values())/len(elo_points_by_season.values())
print("\nOn average, your forecasts would have gotten %s points per season. Elo got %s points per season.\n" % (round(my_avg, 2), round(elo_avg, 2)))
# Out:
# On average, your forecasts would have gotten 640.59 points per season. Elo got 640.57 points per season.

# %% [markdown]
# Now on average of all played games Elo got 640.59 points per season and the point which I've calcualted is also the same.

# %%
# Print forecasts for upcoming games
if len(upcoming_games) > 0:
    print("Forecasts for upcoming games:")
    print('\nDate\t\tTeam1 vs Team2\t\tWinning Proability')
    for game in upcoming_games:
        print("%s\t%s vs. %s\t\t\t%s%%" % (game['date'], game['team1'], game['team2'], int(round(100*game['elo_prob1']))))
# Out:
# Forecasts for upcoming games:
#
# Date		Team1 vs Team2		Winning Proability
# 13-10-19	TB vs. CAR			40%
# 13-10-19	KC vs. HOU			71%
# 13-10-19	BAL vs. CIN			83%
# 13-10-19	CLE vs. SEA			43%
# 13-10-19	MIN vs. PHI			56%
# 13-10-19	MIA vs. WSH			57%
# 13-10-19	JAX vs. NO			35%
# 13-10-19	ARI vs. ATL			45%
# 13-10-19	LAR vs. SF			67%
# 13-10-19	NYJ vs. DAL			30%
# 13-10-19	DEN vs. TEN			48%
# 13-10-19	LAC vs. PIT			61%
# 14-10-19	GB vs. DET			62%
# 17-10-19	DEN vs. KC			31%
# 20-10-19	GB vs. OAK			70%
# 20-10-19	WSH vs. SF			35%
# 20-10-19	NYG vs. ARI			65%
# 20-10-19	BUF vs. MIA			79%
# 20-10-19	CIN vs. JAX			43%
# 20-10-19	ATL vs. LAR			40%
# 20-10-19	DET vs. MIN			52%
# 20-10-19	IND vs. HOU			63%
# 20-10-19	TEN vs. LAC			56%
# 20-10-19	CHI vs. NO			52%
# 20-10-19	SEA vs. BAL			62%
# 20-10-19	DAL vs. PHI			54%
# 21-10-19	NYJ vs. NE			14%
# 24-10-19	MIN vs. WSH			82%
# 27-10-19	DET vs. NYG			74%
# 27-10-19	IND vs. DEN			76%
# 27-10-19	CHI vs. LAC			65%
# 27-10-19	LAR vs. CIN			80%
# 27-10-19	BUF vs. PHI			49%
# 27-10-19	ATL vs. SEA			41%
# 27-10-19	TEN vs. TB			64%
# 27-10-19	JAX vs. NYJ			75%
# 27-10-19	NO vs. ARI			88%
# 27-10-19	SF vs. CAR			58%
# 27-10-19	HOU vs. OAK			70%
# 27-10-19	NE vs. CLE			86%
# 27-10-19	KC vs. GB			72%
# 28-10-19	PIT vs. MIA			80%
# 31-10-19	ARI vs. SF			34%
# 03-11-19	JAX vs. HOU			39%
# 03-11-19	PHI vs. CHI			60%
# 03-11-19	KC vs. MIN			68%
# 03-11-19	BUF vs. WSH			78%
# 03-11-19	PIT vs. IND			53%
# 03-11-19	MIA vs. NYJ			61%
# 03-11-19	CAR vs. TEN			63%
# 03-11-19	OAK vs. DET			51%
# 03-11-19	SEA vs. TB			73%
# 03-11-19	DEN vs. CLE			55%
# 03-11-19	LAC vs. GB			59%
# 03-11-19	BAL vs. NE			38%
# 04-11-19	NYG vs. DAL			38%
# 07-11-19	OAK vs. LAC			48%
# 10-11-19	CLE vs. BUF			52%
# 10-11-19	NYJ vs. NYG			50%
# 10-11-19	CIN vs. BAL			30%
# 10-11-19	CHI vs. DET			68%
# 10-11-19	NO vs. ATL			80%
# 10-11-19	TB vs. ARI			74%
# 10-11-19	TEN vs. KC			42%
# 10-11-19	GB vs. CAR			58%
# 10-11-19	IND vs. MIA			84%
# 10-11-19	PIT vs. LAR			50%
# 10-11-19	DAL vs. MIN			57%
# 11-11-19	SF vs. SEA			52%
# 14-11-19	CLE vs. PIT			51%
# 17-11-19	BAL vs. HOU			62%
# 17-11-19	MIN vs. DEN			76%
# 17-11-19	DET vs. DAL			54%
# 17-11-19	WSH vs. NYJ			63%
# 17-11-19	CAR vs. ATL			71%
# 17-11-19	IND vs. JAX			73%
# 17-11-19	TB vs. NO			37%
# 17-11-19	MIA vs. BUF			35%
# 17-11-19	SF vs. ARI			80%
# 17-11-19	OAK vs. CIN			73%
# 17-11-19	PHI vs. NE			41%
# 17-11-19	LAR vs. CHI			61%
# 18-11-19	LAC vs. KC			36%
# 21-11-19	HOU vs. IND			55%
# 24-11-19	NO vs. CAR			71%
# 24-11-19	ATL vs. TB			56%
# 24-11-19	NYJ vs. OAK			42%
# 24-11-19	WSH vs. DET			38%
# 24-11-19	CHI vs. NYG			80%
# 24-11-19	CLE vs. MIA			74%
# 24-11-19	CIN vs. PIT			35%
# 24-11-19	BUF vs. DEN			70%
# 24-11-19	TEN vs. JAX			66%
# 24-11-19	SF vs. GB			59%
# 24-11-19	NE vs. DAL			79%
# 24-11-19	PHI vs. SEA			60%
# 25-11-19	LAR vs. BAL			63%
# 28-11-19	DET vs. CHI			50%
# 28-11-19	DAL vs. BUF			64%
# 28-11-19	ATL vs. NO			34%
# 01-12-19	MIA vs. PHI			27%
# 01-12-19	CAR vs. WSH			81%
# 01-12-19	CIN vs. NYJ			62%
# 01-12-19	KC vs. OAK			80%
# 01-12-19	BAL vs. SF			63%
# 01-12-19	JAX vs. TB			57%
# 01-12-19	IND vs. TEN			66%
# 01-12-19	NYG vs. GB			40%
# 01-12-19	ARI vs. LAR			27%
# 01-12-19	DEN vs. LAC			45%
# 01-12-19	PIT vs. CLE			67%
# 01-12-19	HOU vs. NE			35%
# 02-12-19	SEA vs. MIN			62%
# 05-12-19	CHI vs. DAL			64%
# 08-12-19	NYJ vs. MIA			58%
# 08-12-19	BUF vs. BAL			52%
# 08-12-19	ATL vs. CAR			47%
# 08-12-19	CLE vs. CIN			74%
# 08-12-19	HOU vs. DEN			73%
# 08-12-19	MIN vs. DET			66%
# 08-12-19	GB vs. WSH			80%
# 08-12-19	NO vs. SF			72%
# 08-12-19	TB vs. IND			46%
# 08-12-19	JAX vs. LAC			49%
# 08-12-19	ARI vs. PIT			36%
# 08-12-19	NE vs. KC			69%
# 08-12-19	OAK vs. TEN			51%
# 08-12-19	LAR vs. SEA			60%
# 09-12-19	PHI vs. NYG			81%
# 12-12-19	BAL vs. NYJ			84%
# 15-12-19	NYG vs. MIA			67%
# 15-12-19	PIT vs. BUF			60%
# 15-12-19	CIN vs. NE			15%
# 15-12-19	CAR vs. SEA			54%
# 15-12-19	DET vs. TB			64%
# 15-12-19	TEN vs. HOU			56%
# 15-12-19	KC vs. DEN			82%
# 15-12-19	WSH vs. PHI			29%
# 15-12-19	GB vs. CHI			53%
# 15-12-19	OAK vs. JAX			58%
# 15-12-19	ARI vs. CLE			44%
# 15-12-19	SF vs. ATL			70%
# 15-12-19	DAL vs. LAR			53%
# 15-12-19	LAC vs. MIN			55%
# 16-12-19	NO vs. IND			68%
# 21-12-19	SF vs. LAR			51%
# 21-12-19	TB vs. HOU			50%
# 21-12-19	LAC vs. OAK			70%
# 21-12-19	NE vs. BUF			82%
# 21-12-19	DEN vs. DET			48%
# 22-12-19	TEN vs. NO			42%
# 22-12-19	CLE vs. BAL			45%
# 22-12-19	IND vs. CAR			62%
# 22-12-19	ATL vs. JAX			58%
# 22-12-19	NYJ vs. PIT			33%
# 22-12-19	MIA vs. CIN			58%
# 22-12-19	WSH vs. NYG			54%
# 22-12-19	PHI vs. DAL			64%
# 22-12-19	SEA vs. ARI			84%
# 22-12-19	CHI vs. KC			52%
# 23-12-19	MIN vs. GB			63%
# 29-12-19	DAL vs. WSH			81%
# 29-12-19	BUF vs. NYJ			80%
# 29-12-19	TB vs. ATL			62%
# 29-12-19	HOU vs. TEN			63%
# 29-12-19	BAL vs. PIT			65%
# 29-12-19	CIN vs. CLE			43%
# 29-12-19	KC vs. LAC			72%
# 29-12-19	JAX vs. IND			44%
# 29-12-19	DET vs. GB			56%
# 29-12-19	CAR vs. NO			46%
# 29-12-19	NYG vs. PHI			33%
# 29-12-19	NE vs. MIA			92%
# 29-12-19	MIN vs. CHI			57%
# 29-12-19	DEN vs. OAK			56%
# 29-12-19	LAR vs. ARI			85%
# 29-12-19	SEA vs. SF			66%

# %% [markdown]
# In the above result I'm forecasting winning probality of matches which are going to happen in 2019.
# For e.g. the first match which is going to happen b/w TB and CAR the winning probabilty of TB is 40%. i.e. CAR have higher chances to win the match.
#
# ---
# #### Summary
# I took three dataset(CSV files) from different sources. My aim was to group the the different dataset to get a meaningful result.
#
# * First I took the NFL games file which had data from 1920 to 2018 and had different columns like season, team1 and team2 names, elo1, elo2, score1, score2, results, etc.
#
# * Then I tried to figure out what is the winning rate of a Home Team and it was 57.10%.
#
# * Then I had set some other variables like K-Factor to calculate the speed at which Elo ratings change and HFA (Home field advantage) and found out the winning probabilty.
#
# * After that I took another CSV file which contained the list of games scheduled for 2019 with date and the two competing teams' names. For this data I have found out probability of the home team's win.
#
# * Then I merged the two dataset and converted it into a Dictionary.
#
# * After that, I took another CSV file which had the elo points of each teams.
#
# * Then, for each game I found out the the winning probabilty of team1. If probabilty is more than 50% than Team1 will have more chances of winning, else Team2 will have more chances.
#
# * For each year first I've calculated the actual elo's points for each game. After that I've found the probable elo's point. As we can see above from my results, the actual and forecasted elo's points are the same.
#
# * Then I've calculated the average elo points per season which was 640.59.
#
# * And finally I've forecasted winning probabilities of the teams participating in the games scheduled in 2019 which I got from the nfl_games_2019 csv file.
